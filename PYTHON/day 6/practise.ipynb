# %%
a=input()
def greet(message):
    
    s="Welcome " + message
    return s

greet("drax")
greet(a)
greet(a)
greet(a)
greet(a)
# greet()
# greet()
# greet()
# Out:
# 'Welcome nejne'

# %%
n1=int(input())
n2=int(input())
op=input()
def calc(num1,num2,o):
    if o == '+':return num1+num2    
    if o == '-':return num1-num2    
    if o == '*':return num1*num2    
    if o == '/':return num1/num2    
    if o == '%':return num1%num2    
    if o == '//':return num1//num2    
    if o == '**':return num1**num2    

calc(n1,n2,op)
# Out:
# 546

# %%
def largest(n1,n2):
    if(n1>n2):
        return a
    elif(n2>n1):
        return n2
    else:
        ("error")
largest(2,4)
# Out:
# 4

# %%
def odd_even(num1):
    if(num1%2==0):
        return "even"
    elif(num1%2!=0):
        return "odd"
    else:
        print("Invalid user")
odd_even(5)
# Out:
# 'odd'

# %%
# Q5
def maxi(*args):
    if not args:
        return "Err"
    bgst = args[0]

    for nm in args:
        if nm > bgst:
            bgst = nm

    return bgst

# %%
def add(a, b):
    return a + b

print(add(10, 20))


def greet(name, city="Varansi"):
    print("Name:", name)
    print("City:", city)

greet("drax")


def student(name, age):
    print("Name:", name)
    print("Age:", age)

student(age=20, name="Utkarsh")

def largest(*numbers):
    print("Largest Number:", max(numbers))

largest(10, 50, 30, 90, 40)


def details(**student):
    print(student)

details(name="Utkarsh", age=21, course="Btech")
# Out:
# 30
# Name: drax
# City: Varansi
# Name: Utkarsh
# Age: 20
# Largest Number: 90
# {'name': 'Utkarsh', 'age': 21, 'course': 'Btech'}
