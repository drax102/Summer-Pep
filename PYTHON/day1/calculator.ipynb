# %%
# print("hello")
# d=10.0
# print(d)


# prompt=input("input your string: ")
# data=input("input your data: ")
# print(prompt)
# print(data)
# x=True
# print( not x)
operator=input("enter your operator: ")
a=input("enter your first number: ")
b=input("enter your second number: ")
if operator=="+":
    print("your result of float(a)+float(b) is: ", float(a)+float(b))
elif operator=="-":
    print("your result of float(a)-float(b) is: ", float(a)-float(b))
elif operator=="*":
    print("your result of float(a)*float(b) is: ",  float(a)*float(b))    
elif operator=="/":
    print("your result of float(a)/float(b) is: ", float(a)/float(b))
elif operator=="%":
    print("your result of float(a)%float(b) is: ", float(a)%float(b))
elif operator=="**":
    print("your result of float(a)**float(b) is: ", float(a)**float(b))
elif operator=="//":
    print("your result of float(a)//float(b) is: ", float(a)//float(b))
elif operator=="&":
    print("your result of float(a)&float(b) is: ", float(a)&float(b))
elif operator=="|":
    print("your result of float(a)|float(b) is: ", float(a)|float(b))
elif operator=="^":
    print("your result of float(a)^float(b) is: ", float(a)^float(b))
elif operator=="<<":
    print("your result of float(a)<<float(b) is: ", float(a)<<float(b)) 
elif operator==">>":
    print("your result of float(a)>>float(b) is: ", float(a)>>float(b))
elif operator=="~":
    print("your result of ~float(a) is: ", ~float(a))
elif operator=="==":
    print("your result of float(a)==float(b) is: ", float(a)==float(b))
elif operator=="!=":
    print("your result of float(a)!=float(b) is: ", float(a)!=float(b))
elif operator==">":
    print("your result of float(a)>float(b) is: ", float(a)>float(b))
elif operator=="<":
    print("your result of float(a)<float(b) is: ", float(a)<float(b))
elif operator==">=":
    print("your result of float(a)>=float(b) is: ", float(a)>=float(b))
elif operator=="<=":
    print("your result of float(a)<=float(b) is: ", float(a)<=float(b))
elif operator=="and":
    print("your result of float(a) and float(b) is: ", float(a) and float(b))
elif operator=="or":
    print("your result of float(a) or float(b) is: ", float(a) or float(b))
elif operator=="not":
    print("your result of not float(a) is: ", not float(a))
elif operator=="is":
    print("your result of float(a) is float(b) is: ", float(a) is float(b))
elif operator=="is not":
    print("your result of float(a) is not float(b) is: ", float(a) is not float(b))
elif operator=="in":
    print("your result of float(a) in float(b) is: ", float(a) in float(b))
elif operator=="not in":
    print("your result of float(a) not in float(b) is: ", float(a) not in float(b))
elif operator=="lambda":
    print("your result of lambda x: float(a) + float(b) is: ", (lambda x: float(a) + float(b))(0))
else:    print("invalid operator")
# Out:
# your result of float(a)+float(b) is:  14.0
