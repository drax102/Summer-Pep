# %%
f=open('File.txt','x')
print(f)
# Out:
# <_io.TextIOWrapper name='File.txt' mode='x' encoding='cp1252'>

# %%
with open('File.txt','a') as f:
    f.write('This text has to be appended at the end')
with open('file.txt') as f:
    l=f.read().splitlines
print(f)
# Out:
# <_io.TextIOWrapper name='file.txt' mode='r' encoding='cp1252'>

# %%
# 1)create a file and write your introduction.
# 2) Read and display file contents.
# 3) append a new line 
# 4)count numbers of lines
# 5)count numbers of words
# 6) search a word
# 7) Copy one file into another
# 8) Convert file content to uppercase.
# 9) Store 5 student names.
# 10) read alternate lines.

# f=open('dic.txt','x')
# print(f)
# with open('dic.txt','a') as f:
#     f.write('This text has to be appended at the end \n')
# with open('dic.txt','a') as f:
#     f.write('Teri toh')
# with open('dic.txt') as f:
#     l=f.readlines()
with open('dic.txt') as f:
    l=f.readline()
print(l)
print(l.count('This'))
print(l.find('This'))
print(len(l))

with open("dic.txt", "r") as f1:
    data = f1.read()

with open("copy.txt", "w") as f2:
    f2.write(data)

print("File copied successfully.")

with open("dic.txt", "r") as f:
    data = f.read()

with open("upper.txt", "w") as f:
    f.write(data.upper())

print("Content converted to uppercase.")...................


with open("students.txt", "w") as f:
    for i in range(5):
        name = input("Enter student name: ")
        f.write(name + "\n")

with open("students.txt", "r") as f:
    lines = f.readlines()

for i in range(0, len(lines), 2):
    print(lines[i].strip())
# Out:
# This text has to be appended at the endThis text has to be appended at the endThis text has to be appended at the endThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the endTeri tohThis text has to be appended at the end
#
# 18
# 0
# 816
# File copied successfully.
# Content converted to uppercase.
# jdwojf
# dkwjf
# jdnwjn
