# %%
def greet(a,b):
    # a=10
    # b=283
    # c="define"
    # print(a*b)
    # print(c)
    # return c
    return a+b
greet()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 9
#       5     # print(a*b)
#       6     # print(c)
#       7     # return c
#       8     return a+b
# ----> 9 greet()
#
# TypeError: greet() missing 2 required positional arguments: 'a' and 'b'
