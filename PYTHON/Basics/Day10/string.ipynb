# %%
for ch in 'Python':
    print(ch)
# Out:
# P
# y
# t
# h
# o
# n

# %%
# MEMBERSHIP

text = "Hello, World!"
print('H' in text)  # True
print('h' in text)  # False
# Out:
# True
# False

# %%
print([f for f in files if f.endswith('.py')])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print([f for f in files if f.endswith('.py')])
#
# NameError: name 'files' is not defined

# %%
reverse_text="hello world"
print(reverse_text[::-1])
# Out:
# dlrow olleh

# %%
vowel="hello world"
print(vowel.count('a') + vowel.count('e') + vowel.count('i') + vowel.count('o') + vowel.count('u'))
# Out:
# 3

# %%
n=input("enter the sentence: ")
def recursion(n):
    if(len(n)==0):
       return 0
    print()
# Out:
# i love recursion
# i love recursion
# i love recursion

# %%
email="drax.com"
if email.find(".com")!= -1 and email.find("@")!= -1:
    print("Email is valid")
else:
    print("Email is not valid")
# Out:
# Email is not valid

# %%
phone="1234567890"
print(phone.replace(phone[0:6], "******"))
# Out:
# ******7890

# %%
occurrence = "hello world hello everyone world hello"
print(occurrence.count('o'))
# Out:
# 6

# %%
st="se bob gh bob gefd bob sdededs bob"

# x=0
# n=""
# for i in range(0, len(n)):
#     if(n.count("bob")==2):
#         print(i-5)
#         break
#     else:
#         x+=1
#         n=st[:x]+n   

# skipped

# %%
#find the freqn of each char in a string

s="hello world harsh harsh hakupa pakoda"
freq={}
for char in s:
    if char in freq:
        freq[char]+=1
    else:
        freq[char]=1

print(freq)
# Out:
# {'h': 6, 'e': 1, 'l': 3, 'o': 3, ' ': 5, 'w': 1, 'r': 3, 'd': 2, 'a': 6, 's': 2, 'k': 2, 'u': 1, 'p': 2}

# %%
word="naman"
print(word == word[::-1])
# Out:
# True

# %%
word="dhinchakpooja"
print(len(word))
# Out:
# 13

# %%
word="harsh is chubby"
print(word.count(' '))
# Out:
# 2
