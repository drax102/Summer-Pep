# %%
# Q1) Accept 5 srtring values from user and store them as part of tuple . Print the elemenmts of tuple with their indices.

t = ()

l = []
for i in range(5):
    s = input("Enter a string: ")
    l.append(s)

t = tuple(l)

for i in range(len(t)):
    print(i, ":", t[i])
# Out:
# 0 : 59st 3493rt fhdk 4929dk
# 1 : 9303
# 2 : 94
# 3 : 040
# 4 : 0393

# %%
# Q2. ACcept 5 string values from user and store them as part of tuple. Print the elements of tuple with their indices in reverse order.

l = []

for i in range(5):
    s = input("Enter a string: ")
    l.append(s)

t = tuple(l)

for i in range(len(t)-1, -1, -1):
    print(i, ":", t[i])
# Out:
# 4 : ndjkwejhdf
# 3 : dkjejkfhio
# 2 : djkwiodjwq
# 1 : dwjknhdj
# 0 : dehiodh

# %%
se={}
print(type(se))
# Out:
# <class 'dict'>

# %%
s={10,20,30}
,

# %%
a={10, 20, 30, 56, 45}

print(len(a), min(a), max(a), sum(a), sorted(a), any(a), all(a), (enumerate(a)))

print(dict(enumerate(a)))
print(list(enumerate(a)))

# %% [markdown]
# [11:09 am, 08/07/2026] DRAX: #### SET OPERATIONS
#
# #### ==============================================================================================
# ####                                   THE BIG FOUR SET OPERATIONS
# #### ==============================================================================================
# ####  Operation            | Symbol | Method                 | What it does
# #### ----------------------|--------|------------------------|-------------------------------------
# ####  Union                |   |    | .union()               | Dono sets ke saare elements ko mila deta hai (removes duplicates).
# ####  Intersection         |   &    | .intersection()        | Sirf wahi elements rakhta hai jo dono sets mein common hain.
# ####  Difference           |   -    | .difference(…
# [11:09 am, 08/07/2026] DRAX: # ==============================================================================================
# #                                   IMPORTANT SET METHODS
# # ==============================================================================================
# #  Method     | Syntax               | What it does
# # ------------|----------------------|----------------------------------------------------------
# #  add        | set.add(item)        | Set mein ek naya element add karta hai.
# #  update     | set.update(iterable) | Ek sath kayi saare elements (list ya set) add karta hai.
# #  remove     | set.remove(item)     | Element delete karta hai. Agar element na ho toh ERROR deta hai.
# #  discard    | set.discard(item)    | SAFE DELETE! Element na bhi ho toh ERROR NAHI deta.
# #  pop        | set.pop()            | Kisi bhi RANDOM element ko nikaal kar delete kar deta hai.
# #  clear      | set.clear()          | Set ke saare elements ko uda kar usey khaali (empty) kar deta hai.
# # ==============================================================================================
#
# # --- LIVE CODE EXAMPLES ---
#
# my_set = {"Python", "Java"}
#
# # 1. add() — Ek item add karna
# my_set.add("C++")
# print("After add:", my_set)          # Output: {'Python', 'Java', 'C++'} (Order random ho sakta hai)
#
#
# # 2. update() — Ek sath multiple items lana
# my_set.update(["JavaScript", "Go"])
# print("After update:", my_set)       # Output: {'Java', 'Python', 'JavaScript', 'C++', 'Go'}
#
#
# # 3. remove() vs discard() [Exam ke liye bohot zaroori concept!]
# # remove() se delete karna:
# my_set.remove("Java")
#
# # Agar main fir se my_set.remove("Java") likhunga, toh Python ERROR (KeyError) de dega.
# # Isliye hum use karte hain discard():
# my_set.discard("Java")               # Java pehle hi delete ho chuka hai, par yeh line ERROR nahi degi!
# print("After discard:", my_set)
#
#
# # 4. pop() — Randomly kuch bhi nikalna
# # Kyunki set unordered hota hai, pop() kisi bhi ek element ko nikaal dega
# deleted_item = my_set.pop()
# print(f"Popped item: {deleted_item}")
# print("After pop:", my_set)
#
#
# # 5. clear() — Sab saaf
# my_set.clear()
# print("After clear:", my_set)        # Output: set() (Khaali set)
#
#
#
# # ==============================================================================================
# #                                       SET COPY METHOD
# # ==============================================================================================
# #  Method     | Syntax               | What it does
# # ------------|----------------------|----------------------------------------------------------
# #  copy       | new_set = set.copy() | Set ki ek alag independent copy banata hai.
# # ==============================================================================================
#
# # --- LIVE CODE EXAMPLE ---
#
# # Humare paas ek original users ka set hai
# original_users = {"Amit", "Rahul", "Priya"}
#
# # Humne copy() ka use karke ek backup set bana liya
# backup_users = original_users.copy()
#
# # Ab agar hum backup wale set mein naye users add ya remove karte hain:
# backup_users.add("Rohan")
# backup_users.remove("Amit")
#
# # Dono ko print karke check karte hain:
# print("Original Users:", original_users)
# # Output: {'Amit', 'Rahul', 'Priya'} -> (Yeh ekdum safe hai, isme koi badlav nahi hua!)
#
# print("Backup Users  :", backup_users)
# # Output: {'Rahul', 'Priya', 'Rohan'} -> (Sirf backup wala change hua)

# %%
A={1,2,3,4}
B={3,4,5,6}
print(A|B)
print(A&B)
print(A-B)
print(A^B)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {1, 2, 5, 6}

# %%
# Remove duplicates
# find common subjects
# compare tuple and sets
# employee tuple
# unique cities.
b=[4,5,35,5,67,64,7]
print(set(b))
c=set(b)
a={1,2,4,5}
print(c&a)
print(c|a)
print(c-a)
print(c^a)
# Out:
# {64, 67, 35, 4, 5, 7}
# {4, 5}
# {64, 1, 2, 67, 35, 4, 5, 7}
# {64, 35, 67, 7}
# {64, 1, 2, 67, 35, 7}

# %%
d={}
print(d)
e={"a":10,"a":20}
print(e)
# Out:
# {}
# {'a': 20}

# %%
student = {
    "Name": "Rahul",
    "Age": 10,
    "Cgpa": 8.5
}

print(student)

print(student["Name"])      # Access using []
print(student.get("Name"))  # Access using get()
print(student.get("Phone")) # Returns None (no error)

# student.pop("City")       # Error: KeyError

student.pop("Age")          # Remove an existing key
print(student)

student.popitem()           # Removes the last inserted key-value pair
print(student)

student.clear()             # Removes all items
print(student)
# Out:
# {'Name': 'Rahul', 'Age': 10, 'Cgpa': 8.5}
# Rahul
# Rahul
# None
# {'Name': 'Rahul', 'Cgpa': 8.5}
# {'Name': 'Rahul'}
# {}

# %%
students={
    101:{"Name":"Rahul","Cgpa":8.9}
}

# %%
square=(x:x*X for i ij range(1,6))
print(square)
.,

# %%
Q)why must dictinary keys be unique?

# %%
q) creaete a student dictionary 
add a new kay
update a existing value.
deletr a key using pop().
print all keys.
print all keys.
traverse using items()
create a nested dictionary
create a dictionary comprehension for cubes.
count frequency  of characters  in a string using a dictionary

student = {
    "Name": "Rahul",
    "Age": 20,
    "CGPA": 8.5
}

print(student)

# %%
student["City"] = "Delhi"

print(student)

student["CGPA"] = 9.2

print(student)

student.pop("Age")

print(student)

print(student.keys())

print(student.values())

for key, value in student.items():
    print(key, ":", value)

students = {
    "Student1": {
        "Name": "Rahul",
        "CGPA": 8.5
    },
    "Student2": {
        "Name": "Aman",
        "CGPA": 9.0
    }
}

print(students)

cubes = {x: x**3 for x in range(1, 6)}

print(cubes)


s = input("Enter a string: ")

freq = {}

for ch in s:
    if ch in freq:
        freq[ch] += 1
    else:
        freq[ch] = 1

print(freq)
# Out:
# {'City': 'Delhi'}
# {'City': 'Delhi', 'CGPA': 9.2}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 9
#       5 student["CGPA"] = 9.2
#       6
#       7 print(student)
#       8
# ----> 9 student.pop("Age")
#      10
#      11 print(student)
#      12
#
# KeyError: 'Age'

# %%
# 1. Store the last 15 temperatures recorded during a day
# Display the lowest, highest and average temperature

temperatures = []

for i in range(15):
    temp = float(input(f"Enter temperature {i + 1}: "))
    temperatures.append(temp)

print("Lowest Temperature:", min(temperatures))
print("Highest Temperature:", max(temperatures))
print("Average Temperature:", sum(temperatures) / len(temperatures))


# 2. Store the unique programming languages known by a class
# Display them alphabetically

languages = {"Python", "Java", "C", "Python", "JavaScript", "C++"}

print("\nProgramming Languages:")

for language in sorted(languages):
    print(language)


# 3. Store coordinates of 8 chess pieces
# Tuple is used because it cannot be modified

chess_pieces = (
    ("King", "E1"),
    ("Queen", "D1"),
    ("Rook1", "A1"),
    ("Rook2", "H1"),
    ("Bishop1", "C1"),
    ("Bishop2", "F1"),
    ("Knight1", "B1"),
    ("Knight2", "G1")
)

print("\nChess Piece Coordinates:")

for piece in chess_pieces:
    print(piece)
