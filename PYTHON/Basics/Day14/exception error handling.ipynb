# %% [markdown]
# <!-- 1) Handle division by zero
# 2)Handle invalid age input
# 3) handle list index error.
# 4) handle directory key error
# 5) handle file not found
# 6) calculator using try-except
# 7)Validate salary(>0).
# 8)Validate password length.
# 9)Employeee bonus calculator
# 10)Shopping bill with invalid quantity -->

# %%
try:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("Result:", a / b)
except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Result: 1.25

# %%
try:
    age = int(input("Enter your age: "))
    print("Age:", age)
except ValueError:
    print("Please enter a valid number.")
# Out:
# Age: 2423

# %%
numbers = [10, 20, 30,40,50,60,70,80,90]

try:
    index = int(input("Enter index: "))
    print(numbers[index])
except IndexError:
    print("Invalid index.")
# Out:
# Invalid index.

# %%
dic=('Atif','modi','amit','rahul')
try:
    d=input("Enter the name")
    print(dic(d))
except KeyError:
    print("key error found")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       1 dic=('Atif','modi','amit','rahul')
#       2 try:
#       3     d=input("Enter the name")
#       4     print(dic(d))
# ----> 5 except KeyError:
#       6     print("key error found")
#       7
#       8
#
# TypeError: 'tuple' object is not callable
