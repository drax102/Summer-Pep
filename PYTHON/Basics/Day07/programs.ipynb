# %%
length=float(input("Enter length"))
breadth=float(input("enter Breadth"))
c=float(length*breadth)
print("The Area of you Rectangular table is :",c)
# Out:
# The Area of you Rectangular table is : 15132.0

# %%
p=float(input("Enter the principle amount:" ))
r=float(input("Enter the ROI: " ))
t=float(input("Enter the tenure: " ))
c=float((p*r*t)/100)
print("The Simple Interest for this principle and time is: ",c)
# Out:
# The Simple Interest for this principle and time is:  100.0

# %%
Celsius=float(input("Enter temperature in Celsius :"))
f=(Celsius* 9/5)+32
print("The temperature after converting into fahrenheit is: ",f)
# Out:
# The temperature after converting into fahrenheit is:  183.2

# %%
def GST(amount, rate):
        if(rate==18):
                gst=(18*amount)/100
        elif(rate==28):
                gst=(28*amount)/100
        elif(rate==5):
                gst=(5*amount)/100
        return (gst+amount)
amount=float(input("Amount of purchase"))
rate=float(input("Gst rate of purchase"))
GST(amount,rate)
# Out:
# 4021.5

# %%
# age=int(input("Enter your age"))
def eligiblitiy(age):
    if(age>17 and age<=22):
        print("You are eligible for schlorship")
        print("COngratulations, You made it!!!!")
    else:
        print("Sorry to inform you that you are not eligible for this schlorship, Sorry for the inconvienence")
a=int(input("Enter you age"))
eligiblitiy(a)
# Out:
# You are eligible for schlorship
# COngratulations, You made it!!!!

# %%
def password(passkey):
    password = ("Utkarsh123")
    if(passkey=="Utkarsh123"):
        print("Login Successfully. You may proceed to the website")
    elif(passkey!="Utkarsh123"):
        print("Verify your password again. Try again")
    else:
        print("Sorry for the inconveince")
c=input("Enter your password: ")
password(c)
# Out:
# Login Successfully. You may proceed to the website

# %%
def info():
    n(input())

# %%
def MRP(amount,quantity,discout):
    # amount=float(input("Enter the amount"))
    # quantity=float(input("quantity: "))
    # discout=float(input("Enter quantity"))
    if(discout!=0):
        c=float((amount*quantity)-discout)
    else:
        c=float(amount*quantity)
    return c
a=float(input("Enter the amount: "))
q=float(input("Enter the quantity: "))
d=float(input("Enter the discount in integer: "))
MRP(a,q,d)
# Out:
# 200.0

# %%
def result(subject):
    for i in range (subject):
        marks=int(input("Enter marks for subject: "))
        if marks >= 40 and marks<=100:
            print("Passsed in this subject")
        else:
            print("Failed in this subject")
    total += marks
    average = total / subject
    print("\nTotal Marks =", total)
    print("Average Marks =", average)

s=int(input("Enter number of subject")) 
# m=(int(input("enter marks of subject")))
result(s)
# Out:
# Failed in this subject
# Passsed in this subject
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[34], line 15
#      11     print("Average Marks =", average)
#      12
#      13 s=int(input("Enter number of subject"))
#      14 # m=(int(input("enter marks of subject")))
# ---> 15 result(s)
#
# Cell In[34], line 8, in result(subject)
#       4         if marks >= 40 and marks<=100:
#       5             print("Passsed in this subject")
#       6         else:
#       7             print("Failed in this subject")
# ----> 8     total += marks
#       9     average = total / subject
#      10     print("\nTotal Marks =", total)
#      11     print("Average Marks =", average)
#
# UnboundLocalError: cannot access local variable 'total' where it is not associated with a value
