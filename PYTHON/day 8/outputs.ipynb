# %%
balance=9
def deposit(x):
    global balance
    balance+=x
    print("balance after deposit:", balance) 
def withdraw(x):
    global balance
    balance-=x
    print("balance after withdraw:", balance)
withdraw(5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          )
deposit(10)
# Out:
# balance after withdraw: 4
# balance after deposit: 14

# %%
x=int(input("Enter a number:"))
y=int(input("Enter another number:"))
ans=lambda x,y:(x+y,x*y)
print(ans(x,y))
# Out:
# (142, 4557)

# %%
n=int(input("Enter a number:"))
cube=lambda x: x*x*x
print(cube(n))
# Out:
# 125

# %%
n=int(input("Enter a number:"))
even_odd=lambda x:x%2==0 
if even_odd(n):
    print("n is even")
else:
    print("odd")
# Out:
# odd

# %%
x=int(input("Enter a number:"))
y=int(input("Enter another number:"))
largest=lambda a,b: a if a>b else b;
print(largest(x,y))
# Out:
# 84

# %%
x=int(input("Enter a number:"))
celsius=lambda c:(c*9/5+32)
print(celsius(x))
# Out:
# 37.4

# %%
n=int(input("Enter a number:"))
MT =list(map(lambda x:n*x, range(1,11)))
print(MT)
# Out:
# [84, 168, 252, 336, 420, 504, 588, 672, 756, 840]

# %%
def io(x):
    city=0
    print("City number is:", city)
io(city)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 def io(x):
#       2     city=0
#       3     print("City number is:", city)
# ----> 4 io(city)
#
# NameError: name 'city' is not defined
