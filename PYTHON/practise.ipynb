# %%
a=input("enter your age: " )
print("your age is: ",a)
if(int(a) >= 18):
    print("you are eligible to vote")
else:
    print("you are not eligible to vote")
# Out:
# your age is:  84
# you are eligible to vote

# %%
a=input("enter a number: " )
if(int(a)<0):
    print("the number is negative")
elif(int(a)==0):
    print("the number is zero")
else:
    print("the number is positive")
# Out:
# the number is zero

# %%
b=int(input("enter a number: " ))
print("the number is: ",b)
if(b==2 or b==3 or b==5 or b==7):
    print("the number is prime")
else:
    print("the number is not prime")
# Out:
# the number is:  9
# the number is not prime

# %%
orders=int(input("enter the number of orders: "))
print("the number of orders in a day is: ",orders)
if(orders>5 and orders<10):
    print("your coupon code is: 'IND100'")
    print("good job! you have received a coupon code for your orders. Get upto 5% discount on your next order")
elif(orders>10 and orders<15):
    print("your coupon code is: 'IND200'")
    print("good job! you have received a coupon code for your orders. Get upto 10% discount on your next order")
elif(orders>15 and orders<20):
    print("your coupon code is: 'IND300'")
    print("good job! you have received a coupon code for your orders. Get upto 15% discount on your next order")
elif(orders>20):
    print("Wallet Top-up:100Rs Credited")
    print("good job! you have received a amount of 100Rs in your wallet for your orders. Get upto 20% discount on your next order")
else:
    print("Do order more than 5 to get a coupon code for your next order")
    print("no coupon available")
# Out:
# the number of orders in a day is:  999
# Wallet Top-up:100Rs Credited
# good job! you have received a amount of 100Rs in your wallet for your orders. Get upto 20% discount on your next order

# %%
order_amount=int(input("enter the order amount: "))
if(order_amount>500 and order_amount<1000):
    print("your coupon code is: 'IND100'")
    print("good job! you have received a coupon code for your orders. Get upto 5% discount on your next order")
elif(order_amount>1000 and order_amount<5000):
    print("your coupon code is: 'IND200'")
    print("good job! you have received a coupon code for your orders. Get upto 25% discount on your next order")
elif(order_amount>5000):
    print("Wallet Top-up:100Rs Credited")
    print("good job! you have received a amount of 100Rs in your wallet for your orders. Get upto 35% discount on your next order")
else:
    print("Do order more than 500 to get a coupon code for your next order")
    print("no coupon available")
# Out:
# your coupon code is: 'IND100'
# good job! you have received a coupon code for your orders. Get upto 5% discount on your next order

# %%
salary =int(input("Enter your salary: "))
if(salary>150000):
    gift = "Iphone"
    print("You will get a gift of",gift)
elif(salary>100000):
    gift = "Samsung"
    print("You will get a gift of ",gift)
elif(salary>75000):
    gift = "Redmi"
    print("You will get a gift of ",gift)
else:
    gift = "Nothing"
# Out:
# You will get a gift of Iphone
